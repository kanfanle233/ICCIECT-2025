# %% [markdown]
# # Canny算法的实现

# %%
# 0.读取图片 - 读取灰度图像，cv.imread第二个参数0表示以灰度模式读取

# %%
# 1. 平滑 - 使用高斯滤波器对图像降噪，cv.GaussianBlur(img, (ksize, ksize), sigma)

# %%
# 2. 计算梯度 - 使用Sobel算子计算x和y方向的梯度，再合成梯度幅值和方向

# %%
# 3. 细化边缘 - 非极大值抑制（NMS），沿梯度方向比较邻域像素，保留局部最大值

# %%
# 4.双阈值抑制 - 设定高阈值和低阈值：高于高阈值为强边缘，介于两者之间为弱边缘，低于低阈值抑制
