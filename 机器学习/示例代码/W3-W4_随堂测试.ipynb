# %% [markdown]
# 1.Dataframe的转换方式？
# 2.懂得如何看箱型图？
# 3.在使用train_test_split()拆分训练集和测试集时，如何理解random_state
# 4.学会查看混淆矩阵
# 5.精确度、召回率、F1分数如何计算？
# 6.懂得计算以下的统计概念
#  均值（Mean） 数据的平均值 df.mean()
#  中位数（Median） 数据的中间值 df.median()
#  众数（Mode） 出现次数最多的值 df.mode()
#  标准差（Std） 反映数据离散程度 df.std()
#  方差（Variance） 反映数据波动大小 df.var()
#  最大值/最小值 数据的上下界 df.max() / df.min()
#  四分位数（Quantiles） 数据的分布范围 df.describe()
# 7.记住并学会计算欧氏距离、曼哈顿距离、闵可夫斯基距离；记住并学会计算余弦相似度、Jaccard相似度和皮尔逊相关系数

# %% [markdown]
# # 题目部分
#
# # 一. DataFrame 的概念与转换
#
# ## 1.在 Pandas 中，DataFrame 的本质是什么？
# ## A) 一个单列的数据集合（类似 Excel 单列）
# ## B) 一个二维的表格数据结构，类似于 Excel 表格
# ## C) 只能存储数值数据的数组
# ## D) 只能存储字符串数据的列表
# ## 2.以下哪种方法可以将 Pandas DataFrame 转换为 NumPy 数组？
# ## A) df.to_numpy()
# ## B) df.to_list()
# ## C) df.to_dict()
# ## D) df.to_dataframe()
#
# ## 3.andas DataFrame 由 _________ 和 _________ 组成（数据结构的基本单元）。
# ## 4.将 DataFrame 转换为 字典 的方法是 _________。
# ## 5.将 DataFrame 转换为 CSV 文件 并保存的方法是 _________。
#
# ## ⸻
#
# # 二. 如何看箱型图
#
# ## 6.箱型图（Boxplot）可以用于检测数据中的异常值。（✅ / ❌）
# ## 7.箱型图的中间线代表数据的均值。（✅ / ❌）
#
# ## 8.在箱型图中，上下四分位数（Q1, Q3）定义了数据的 _________。
# ## 9.数据点若超出 1.5 × IQR（四分位距），通常被认为是 _________。
#
# ## ⸻
#
# # 三. train_test_split() 和 random_state
#
# ## 10.random_state=42 在 train_test_split() 中的作用是：
# ## A) 使每次数据拆分结果相同
# ## B) 让训练集更大
# ## C) 让测试集更大
# ## D) 随机打乱数据
#
# ## 11.train_test_split(df, test_size=0.2, random_state=42) 作用是将数据集按 _________ 的比例拆分为训练集和测试集。
# ## 12.random_state 主要用于 _________ 结果，以便实验可以复现。
#
# # ⸻
#
# # 四. 混淆矩阵
#
# ## 13.在二分类任务中，混淆矩阵的哪一项代表 模型误报（False Positive, FP）？
# ## A) 预测 1，实际是 1
# ## B) 预测 0，实际是 1
# ## C) 预测 1，实际是 0
# ## D) 预测 0，实际是 0
#
# ## 14.在 confusion_matrix(y_true, y_pred) 的输出中，左上角的值代表 _________（TP/TN/FP/FN）。
# ## 15.classification_report(y_true, y_pred) 可以直接计算 、、_________ 三个关键分类指标。
#
# # ⸻
#
# # 五. 精确度、召回率、F1 分数计算
#
# ## 16.精确度（Precision）的计算公式是：
# ## A) $\frac{TP}{TP + FP}$
# ## B) $\frac{TP}{TP + FN}$
# ## C) $\frac{TN}{TN + FP}$
# ## D) $\frac{TP + TN}{TP + TN + FP + FN}$
# ## 17.F1-score 的计算公式是：
# ## A) $\frac{2 \times \text{Precision} \times \text{Recall}}{\text{Precision} + \text{Recall}}$
# ## B) $\frac{TP + FN}{TP + TN}$
# ## C) $\frac{TN}{TP + TN}$
# ## D) $\frac{FP + FN}{TP + TN + FP + FN}$
#
# # ⸻
#
# # 六. 统计概念计算
#
# ## 18.计算数据的 均值（Mean） 使用 _________ 方法。
# ## 19.计算数据的 中位数（Median） 使用 _________ 方法。
# ## 20.计算数据的 标准差（Std） 使用 _________ 方法。
# ## 21.计算数据的 方差（Variance） 使用 _________ 方法。
# ## 22.计算数据的最小值和最大值，分别使用 _________ 和 _________ 方法。
# ## 23.df.describe() 返回的数据包括 、、_________（至少写 3 个统计量）。
# ## 24.均值（Mean） 的作用是什么？
# ## A) 数据集中出现次数最多的值
# ## B) 计算数据的平均值，衡量数据的中心位置
# ## C) 计算数据的离散程度，衡量数据分布的差异
# ## D) 计算数据的变化幅度
# ## 25.	标准差（Standard Deviation） 衡量的是：
# ## A) 数据的平均值
# ## B) 数据集中出现最多的值
# ## C) 数据离散程度，即数据偏离均值的程度
# ## D) 数据的最小值和最大值
# ## 26.众数（Mode） 的定义是什么？
# ## A) 数据中最大的值
# ## B) 数据集中最常出现的值
# ## C) 数据的平均值
# ## D) 数据的标准差
# ## 27.方差（Variance） 与 标准差 之间的关系是什么？
# ## A) 方差是标准差的平方
# ## B) 标准差是方差的平方
# ## C) 方差和标准差没有关系
# ## D) 方差等于标准差乘以均值
# ## 28.四分位数（Quantiles） 是什么？
# ## A) 用于描述数据的离散程度
# ## B) 数据排序后，按照 25%、50%、75% 位置划分的点
# ## C) 计算数据的变化幅度
# ## D) 计算数据的极差
#
# ## (填空题)
# ## 29. 计算数据的 中位数（Median） 是找到数据排序后的 _________（位置）。
# ## 30. 众数（Mode） 适用于 _________ 数据，例如调查问卷中的 “最喜欢的颜色”。
# ## 31. 标准差（Std） 反映的是数据的 _________，标准差越大，数据的波动性越 _________。
# ## 32. 方差（Variance） 的单位是原数据的 _________ 次方。
# ## 33. 在 df.describe() 的输出中，、、_________（至少写 3 个统计量）用于描述数据的分布情况。
#
# # ⸻
#
# # 七. 距离计算
#
# ## 34.欧氏距离（Euclidean Distance）的计算公式是：
# ## A) $d(A, B) = \sum |A_i - B_i|$
# ## B) $d(A, B) = \left(\sum |A_i - B_i|^p \right)^{\frac{1}{p}}$
# ## C) $d(A, B) = \sqrt{\sum (A_i - B_i)^2}$
# ## D) $d(A, B) = \max |A_i - B_i|$
# ## 35.皮尔逊相关系数的计算公式是：
# ## A) $J(A, B) = \frac{|A \cap B|}{|A \cup B|}$
# ## B) $r = \frac{\sum (X_i - \bar{X}) (Y_i - \bar{Y})}{\sqrt{\sum (X_i - \bar{X})^2} \times \sqrt{\sum (Y_i - \bar{Y})^2}}$
# ## C) $S(A,B) = \frac{A \cdot B}{||A|| \times ||B||}$
# ## D) $d(A, B) = \sqrt{\sum (A_i - B_i)^2}$
#
#
# ## 36.计算 曼哈顿距离（Manhattan Distance） 使用公式 _________。
# ## 37.计算 余弦相似度（Cosine Similarity） 使用公式 _________。
# ## 38.计算 Jaccard 相似度（Jaccard Similarity） 需要计算两个集合的 _________ 和 _________ 之比。
