# %% [markdown]
# 1.已知某二分类问题混淆矩阵中：TP=40，FP=10，FN=5，TN=45，请计算精确度。
#
# 2.已知某二分类问题混淆矩阵中：TP=30，FP=20，FN=10，TN=40，请计算召回率。
#
# 3.某分类模型的 Precision 为 0.8，Recall 为 0.6，请计算 F1 分数。
#
# 4.某数据集有5个类别的样本占比为：0.1，0.2，0.3，0.2，0.2，请计算信息熵。
#
# 5.在 PCA 中，若协方差矩阵的特征值为 [5, 2, 0.5]，请计算第一个主成分的方差贡献率。
#
# 6.有两个样本 A = [2, 3], B = [5, 7]，请计算它们的欧氏距离。
#
# 7.若一组数据的均值为 50，标准差为 10，则样本值 x=70 的 Z-score 为多少？
#
# 8.若数据集有6个样本，其 Y=是 有4个，Y=否 有2个，请计算信息熵 H(Y)。
#
# 9.某模型在测试集中预测出 TP=50, FP=5, FN=10, TN=35。请分别计算 Precision、Recall 和 F1-score，并给出最终结论。
#
# 10.若一个数据集 Y 有三个类别，占比分别为 0.5, 0.3, 0.2，某特征 X 拆分为两组 A 和 B：A 组占 60%，A 中 Y 类别分布为[0.4, 0.4,
# 0.2]；B 为其余。请计算 H(Y|X)。
#
# 11.若某特征的最大值为80，最小值为20，现有一个值 x=100，使用 Min-Max 归一化后结果是多少？该情况是否合理？
#
# 12.PCA 中协方差矩阵的特征值为 [4, 3, 2, 1]，请问选前两个主成分能保留多少信息？若要保留 95% 信息需至少几个主成分？
#
# 13.样本 A = [1,2,3,4]，B = [4,3,2,1]，请分别计算它们的欧氏距离和余弦相似度。
#
# 14.已知某模型预测正确率为 90%，测试集总样本数为 200，其中实际正类有 120 个，预测正类为 110 个，请估算 TP, FP, FN, TN。
